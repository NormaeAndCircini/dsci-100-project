# %% [markdown]
# # DSCI 100 Project Individual Planning Report

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(cowplot)
options(repr.matrix.max.rows = 6)

# %%
# LOAD PLAYERS AND SESSIONS INTO R
players <- read_delim("data/players.csv")
sessions <- read_delim("data/sessions.csv")

# %% [markdown]
# ## (1) Data Description

# %%
# PLAYERS SUMMARY STATISTICS
summary_players <- summary(players)
catagories_experience <- unique(players$experience)
catagories_gender <- unique(players$gender)

summary_players
catagories_experience
catagories_gender

# SESSIONS SUMMARY STATISTICS
summary_sessions <- summary(sessions)

summary_sessions

# %% [markdown]
# the number of observations
# summary statistics (report values to 2 decimal places)
# number of variables
# name and type of variables
# what the variables mean
# any issues you see in the data, any other potential issues related to things you cannot directly see
# how the data were collected

# %% [markdown]
# The data consist of two file: `players` and `sessions`.
#
# `players` is a list of all unique players, including data about each player. There are
# - 196 rows (observations).
# - 7 variables.
#   | variable  | type | meaning
#
# `sessions` is a lits of individual play sessions by each player, including data about the session.

# %% [markdown]
# ## (2) Questions

# %% [markdown]
# ## (3) Exploratory Data Analysis and Visualization

# %%
players
sessions

# %% [markdown]
# ## (4) Methods and Plan

# %% [markdown]
# ## (5) GitHub Repository
